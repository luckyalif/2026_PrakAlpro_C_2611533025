# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“PENGENALAN PYTHON, VS CODE, DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Lucky Alif Pratama**
#
# **2611533025**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo UNAND 3.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ---
# <h1 align="center"> KATA PENGANTAR</h1>
#
#
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pengenalan Python, VS Code, dan Koneksi ke GitHub yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan pengenalan lingkungan kerja pemrograman Python, pemanfaatan ekstensinya seperti Python Debugger dan Jupyter pada Visual Studio Code, serta mekanisme pengintegrasian repositori lokal ke GitHub.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar sintaksis Python—seperti cetak keluaran (output stream), manipulasi string, dan sintaksis komentar—serta pengelolaan kontrol versi kode pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# <br>
# <div align="right" style="margin-left:-30px;">
# Padang, September 2026
# <br>
# <br>
# <br>
# <br>
# <br>
# Lucky Alif Pratama
# <br>
# 2611533025
# </div>

# %% [markdown]
# ---
# <h1 align="center">BAB I<br>PENDAHULUAN</h1>
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi informasi dan industri perangkat lunak (software engineering) menuntut para praktisi untuk memiliki pemahaman yang kuat mengenai dasar-dasar pemrograman serta efisiensi dalam lingkungan pengembangan. Dalam ranah ilmu komputer dan struktur data, pemilihan bahasa pemrograman yang fleksibel menjadi fondasi utama. Bahasa pemrograman Python hadir sebagai salah satu bahasa tingkat tinggi yang sangat populer karena memiliki sintaksis yang bersih, sederhana, dan mudah dipahami, namun tetap memiliki kapabilitas tinggi dalam menangani berbagai domain aplikasi dari skrip sederhana hingga analisis data (Severance, 2016).
#
# Penguasaan bahasa pemrograman perlu didukung oleh pemanfaatan Integrated Development Environment (IDE) yang andal. Visual Studio Code (VS Code) merupakan kode editor terkemuka yang menyediakan ekosistem luas untuk mendukung produktivitas pemrograman (Microsoft, 2023). Melalui integrasi ekstensi seperti Python Debugger dan Jupyter, proses penulisan kode, analisis kesalahan (debugging), pengujian interaktif, hingga visualisasi data dapat dilakukan secara efisien dalam satu lingkungan kerja yang terpadu (Kluyver et al., 2016).
#
# Selain penulisan dan pengujian kode, aspek pengelolaan kode sumber (source code management) merupakan kualifikasi krusial dalam pengembangan perangkat lunak modern. Penggunaan Git dan GitHub sebagai platform version control system memungkinkan pengembang untuk melacak setiap perubahan skrip, mengelola versi proyek secara terstruktur, serta berkolaborasi secara efisien (Chacon & Straub, 2014). Konsep version control ini penting dipelajari sejak dini agar praktikan terbiasa dengan standar industri.
#
# Oleh karena itu, praktikum Pengenalan Python, VS Code, dan Koneksi ke GitHub pada Pertemuan 1 mata kuliah Praktikum Struktur Data ini penting untuk dilaksanakan. Melalui praktikum ini, praktikan tidak hanya dibekali dengan pemahaman sintaksis dasar Python dan luaran (output), tetapi juga mampu mengonfigurasi alat kerja pemrograman serta menghubungkan repositori lokal ke platform GitHub sebagai langkah awal dalam membangun proyek yang terstruktur.
#
# ## 1.2 Tujuan
# 1. Mengenal dan menguasai konsep dasar Python, mencakup fungsi output stream (`print`), penggunaan string concatenation, manipulasi karakter escape, serta penerapan komentar multi-baris.
#
# 2. Mengonfigurasi dan mengoperasikan lingkungan kerja Visual Studio Code (VS Code) beserta ekstensi Python Debugger dan Jupyter Notebook untuk proses penulisan dan pengujian kode.
#
# 3. Memahami dan menerapkan integrasi version control system dengan menghubungkan repositori lokal pada VS Code ke platform GitHub untuk pengelolaan skrip proyek.
#
# ## 1.3 Manfaat
# 1. Bagi Praktikan: Meningkatkan pemahaman teknis dalam mengoperasikan tools pemrograman standar industri serta melatih penyusunan kode yang rapi dan terstruktur.
#
# 2. Bagi Akademik: Menjadi tolok ukur ketercapaian pemahaman mahasiswa pada materi dasar pemrograman sebagai fondasi sebelum mempelajari materi struktur data yang lebih kompleks.

# %% [markdown]
# ---
# <h1 align="center"> BAB II <br> PEMBAHASAN <h1>
#
# ## 2.1 Dasar Teori
# Penjelasan mengenai konsep dan teori yang mendasari pelaksanaan praktikum ini meliputi:
#
# 1. Konsep Bahasa Pemrograman Python dan Sintaksis DasarnyaPython merupakan bahasa pemrograman tingkat tinggi yang bersifat interpreted dan berorientasi objek. Python menekankan pada tingkat keterbacaan kode (code readability) dengan sintaksis yang memungkinkan pengembang mengekspresikan konsep dalam beberapa baris kode dibandingkan dengan bahasa seperti C++ atau Java (Severance, 2016). Beberapa elemen penting sintaksis dasar Python mencakup:
#
#     - Pencetakan Luaran (Output Stream): Menggunakan fungsi `print()` untuk menampilkan teks atau data ke layar console.
#     - Penggabungan String (String Concatenation): Penggabungan beberapa teks menjadi satu kesatuan menggunakan operator `+`.
#     - Karakter Escape (Escape Sequence): Karakter khusus yang diawali dengan tanda backslash (`\`), seperti `\\` untuk menampilkan karakter backslash asli agar tidak terbaca sebagai perintah sistem.
#     - Komentar (Comments): Bagian kode yang diabaikan oleh penerjemah (interpreter), dapat berupa satu baris (diawali `#`) atau multi-baris (diapit kuotasi tiga `"""`), berfungsi sebagai dokumentasi kode.
# 2. Lingkungan Kerja Pemrograman (VS Code, Python Debugger, dan Jupyter)Integrated Development Environment (IDE) dan kode editor sangat berperan dalam meningkatkan efisiensi pengembangan perangkat lunak (Microsoft, 2023).
#
#     - Visual Studio Code (VS Code): Kode editor ringan yang memiliki integrasi luas dengan berbagai alat pemrograman.
#     - Python Debugger: Fitur untuk melacak dan mendeteksi kesalahan (bugs) pada kode secara sistematis dengan menghentikan eksekusi pada titik tertentu (breakpoint) atau mengeksekusi kode baris demi baris.
#     - Jupyter: Lingkungan komputasi interaktif (interactive computing) yang memungkinkan penulisan serta eksekusi potongan kode (code cells) secara terpisah, mempermudah pengujian instan dan analisis data (Kluyver et al., 2016).
#
# 3. Pengelolaan Kontrol Versi (Version Control System) dengan Git dan GitHubVersion Control System (VCS) adalah sistem yang mencatat setiap perubahan pada berkas kode dari waktu ke waktu (Chacon & Straub, 2014).
#     - Git: Perangkat lunak Distributed Version Control System (DVCS) yang berjalan secara lokal di komputer pengembang untuk mengacak riwayat revisi kode.
#     - GitHub: Platform berbasis cloud yang menyimpan repositori Git. GitHub memungkinkan pengembang melakukan pencadangan kode secara terpusat, mengelola riwayat proyek, serta berkolaborasi dengan pengembang lain secara terstruktur.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "A_2611533025"
# Pengembangan program berbasis Python ini dilakukan melalui Visual Studio Code. Penggunaan Python pada praktikum ini bertujuan untuk membuat dan menjalankan program sederhana guna memahami dasar-dasar sintaksis bahasa python.

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("Departemen Informatika")
print("Universitas Andalas")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini " + "dibuat oleh " 
 + "Lucky Alif Pratama_2611533025")
# Out:
# Hello World
#
# Departemen Informatika
# Universitas Andalas
# / \ // \\ /// \\\
# program ini dibuat oleh Lucky Alif Pratama_2611533025

# %% [markdown]
# **Penjelasan :**
# 1. Tanda `#` digunakan untuk membuat komentar satu baris (single-line comment).
# 2. Tanda `"""` digunakan untuk membuat komentar multi-baris (multiline comment) atau teks yang berjumlah lebih dari satu baris.
# 3. Fungsi `print()` digunakan untuk menampilkan data atau teks ke layar console (terminal).
# 4. Tanda `+` dalam fungsi print digunakan untuk menggabungkan beberapa teks (string concatenation).
# 5. Tanda `\\` (escape sequence) digunakan khusus agar karakter backslash bisa ikut tercetak ke layar tanpa memicu kesalahan sistem.
# 6. Program Python ini dapat dieksekusi melalui terminal atau langsung menggunakan fitur Run yang disediakan pada VS Code.

# %% [markdown]
# ### 2.2.2 Program Repository GitHub
# Setelah program dibuat dan diuji pada VS Code, proyek dihubungkan ke platform GitHub. Repositori ini berfungsi untuk menyimpan, mengelola, dan mengamankan berkas kode program secara daring (online).
#
# Tahapan yang dilakukan yaitu:
# 1. Membuat repositori baru pada halaman GitHub.
# 2. Membuka folder proyek menggunakan VS Code.
# 3. Membuka terminal terintegrasi pada VS Code.
# 4. Menginisialisasi Git pada folder proyek lokal.
# 5. Menambahkan berkas ke dalam staging area.
# 6. Membuat commit untuk menyimpan riwayat perubahan.
# 7. Menghubungkan repositori lokal dengan repositori di GitHub.
# 8. Melakukan push untuk mengunggah kode ke GitHub.
#
# Contoh perintah (command) yang digunakan pada terminal:

# %%
git init
git add .
git commit -m "Initial commit"
git branch -M main
git remote add origin https://github.com/username/nama-repository.git
git push -u origin main

# %% [markdown]
# 1. `git init`: Digunakan untuk membuat dan menginisialisasi repositori Git baru pada folder proyek lokal.
# 2. `git add .`: Digunakan untuk menambahkan seluruh berkas dan perubahan pada proyek ke dalam staging area.
# 3. `git commit`: Digunakan untuk menyimpan riwayat perubahan dari staging area disertai pesan deskriptif.
# 4. `git branch -M main`: Digunakan untuk mengubah atau mengonfirmasi nama cabang (branch) utama menjadi main.
# 5. `git remote add origin`: Digunakan untuk menghubungkan repositori lokal dengan repositori yang telah dibuat di GitHub.
# 6. `git push`: Digunakan untuk mengunggah berkas dan riwayat commit dari komputer lokal ke repositori GitHub.

# %% [markdown]
# ---
# <h1 align="center">BAB III<br>KESIMPULAN </h1>
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa penggunaan bahasa pemrograman Python, editor Visual Studio Code, serta sistem kontrol versi Git dan GitHub berhasil dikuasai sebagai fondasi utama dalam lingkungan pengembangan perangkat lunak.
#
# Dalam konteks pemrograman Python, konsep ini memanfaatkan sintaksis yang sederhana dan ekosistem tools yang terintegrasi (seperti Python Debugger dan Jupyter pada VS Code), serta platform GitHub untuk menyimpan dan mengelola versi kode secara daring, sehingga proses penulisan, pengujian, hingga dokumentasi program dapat dilakukan secara lebih efisien, terstruktur, dan siap untuk pengembangan proyek secara kolaboratif.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# 1. Chacon, S., & Straub, B. (2014). Pro Git (2nd ed.). Apress.https://git-scm.com/book/en/v2
#
# 2. Kluyver, T., Ragan-Kelley, B., Pérez, F., Granger, B. E., Bussonnier, M., Frederic, J., Fortin, F. A., Slemmer, M., & Willing, C. (2016). Jupyter Notebooks-a publishing format for reproducible computational workflows. Positioning and Power in Academic Publishing: Players, Agents and Agendas, 87-90.https://ebooks.iospress.nl/volumearticle/44158
#
# 3. Microsoft. (2023). Visual Studio Code Documentation: Python in VS Code. Microsoft Docs.https://code.visualstudio.com/docs/python/python-tutorial
#
# 4. Severance, C. R. (2016). Python for Everybody: Exploring Data in Python 3. CreateSpace Independent Publishing Platform.https://www.py4e.com/book
